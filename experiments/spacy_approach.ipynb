# %%
import re
import spacy
import requests
from bs4 import BeautifulSoup
from collections import Counter

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
url = "https://www.gutenberg.org/cache/epub/345/pg345.txt"

# %%
raw_text = requests.get(url).text

# %%
import string

def remove_punctuation(input_string):
    # Make a translation table that maps all punctuation characters to None
    translator = str.maketrans("", "", string.punctuation)

    # Apply the translation table to the input string
    result = input_string.translate(translator)

    return result

# %%
def preprocess_text(raw_text):
    response_pretty = BeautifulSoup(raw_text, 'html.parser')
    page_text = response_pretty.get_text()
    page_text = re.sub(r'[^\x00-\x7F]+', '', page_text)
    page_text = page_text.replace("\r\n", " ").replace("'s", " ")
    # page_text = page_text.replace("'s", " ")
    # " ".join(page_text.split())
    page_text = re.sub(r'\s+', ' ', page_text)

    return remove_punctuation(page_text)

# %%
words = word_tokenize(raw_text)

# Get the list of English stop words
stop_words = set(stopwords.words('english'))

# Remove stop words from the text
filtered_text = [word for word in words if word.lower() not in stop_words]

# Reconstruct the text without stop words
filtered_text = ' '.join(filtered_text)

# %%
preprocessed_text = preprocess_text(raw_text)

# %%
preprocessed_text
# Out:
# 'The Project Gutenberg eBook of Dracula This ebook is for the use of anyone anywhere in the United States and most other parts of the world at no cost and with almost no restrictions whatsoever You may copy it give it away or reuse it under the terms of the Project Gutenberg License included with this ebook or online at wwwgutenbergorg If you are not located in the United States you will have to check the laws of the country where you are located before using this eBook Title Dracula Author Bram Stoker Release date October 1 1995 eBook 345 Most recently updated July 30 2023 Language English  START OF THE PROJECT GUTENBERG EBOOK DRACULA  DRACULA by Bram Stoker Illustration colophon NEW YORK GROSSET  DUNLAP Publishers Copyright 1897 in the United States of America according to Act of Congress by Bram Stoker All rights reserved PRINTED IN THE UNITED STATES AT THE COUNTRY LIFE PRESS GARDEN CITY NY TO MY DEAR FRIEND HOMMYBEG Contents CHAPTER I Jonathan Harkers Journal CHAPTER II Jonathan Harkers Journal CHAPTER III Jonathan Harkers Journal CHAPTER IV Jonathan Harkers Journal CHAPTER V LettersLucy and Mina CHAPTER VI Mina Murrays Journal CHAPTER VII Cutting from The Dailygraph 8 August CHAPTER VIII Mina Murrays Journal CHAPTER IX Mina Murrays Journal CHAPTER X Mina Murrays Journal CHAPTER XI Lucy Westenras Diary CHAPTER XII Dr Sewards Diary CHAPTER XIII Dr Sewards Diary CHAPTER XIV Mina Harkers Journal CHAPTER XV Dr Sewards Diary CHAPTER XVI Dr Sewards Diary CHAPTER XVII Dr Sewards Diary CHAPTER XVIII Dr Sewards Diary CHAPTER XIX Jonathan Harkers Journal CHAPTER XX Jonathan Harkers Journal CHAPTER XXI Dr Sewards Diary CHAPTER XXII Jonathan Harkers Journal CHAPTER XXIII Dr Sewards Diary CHAPTER XXIV Dr Sewards Phonograph Diary spoken by Van Helsing CHAPTER XXV Dr Sewards Diary CHAPTER XXVI Dr Sewards Diary CHAPTER XXVII Mina Harkers Journal How these papers have been placed in sequence will be made manifest in the reading of them All needless matters have been eliminated so that a history almost at variance with the possibilities of laterday belief may stand forth as simple fact There is throughout no statement of past things wherein memory may err for all the records chosen are exactly contemporary given from the standpoints and within the range of knowledge of those who made them DRACULA CHAPTER I JONATHAN HARKERS JOURNAL Kept in shorthand 3 May BistritzLeft Munich at 835 P M on 1st May arriving at Vienna early next morning should have arrived at 646 but train was an hour late BudaPesth seems a wonderful place from the glimpse which I got of it from the train and the little I could walk through the streets I feared to go very far from the station as we had arrived late and would start as near the correct time as possible The impression I had was that we were leaving the West and entering the East the most western of splendid bridges over the Danube which is here of noble width and depth took us among the traditions of Turkish rule We left in pretty good time and came after nightfall to Klausenburgh Here I stopped for the night at the Hotel Royale I had for dinner or rather supper a chicken done up some way with red pepper which was very good but thirsty Mem get recipe for Mina I asked the waiter and he said it was called paprika hendl and that as it was a national dish I should be able to get it anywhere along the Carpathians I found my smattering of German very useful here indeed I dont know how I should be able to get on without it Having had some time at my disposal when in London I had visited the British Museum and made search among the books and maps in the library regarding Transylvania it had struck me that some foreknowledge of the country could hardly fail to have some importance in dealing with a nobleman of that country I find that the district he named is in the extreme east of the country just on the borders of three states Transylvania Moldavia and Bukovina in the midst of the Carpathian mountains one of the wildest  ...

# %%
filtered_text
# Out:
# '\ufeffThe Project Gutenberg eBook Dracula ebook use anyone anywhere United States parts world cost almost restrictions whatsoever . may copy , give away re-use terms Project Gutenberg License included ebook online www.gutenberg.org . located United States , check laws country located using eBook . Title : Dracula Author : Bram Stoker Release date : October 1 , 1995 [ eBook # 345 ] recently updated : July 30 , 2023 Language : English * * * START PROJECT GUTENBERG EBOOK DRACULA * * * DRACULA _by_ Bram Stoker [ Illustration : colophon ] NEW YORK GROSSET & DUNLAP _Publishers_ Copyright , 1897 , United States America , according Act Congress , Bram Stoker [ _All rights reserved._ ] PRINTED UNITED STATES COUNTRY LIFE PRESS , GARDEN CITY , N.Y. DEAR FRIEND HOMMY-BEG Contents CHAPTER I. Jonathan Harker ’ Journal CHAPTER II . Jonathan Harker ’ Journal CHAPTER III . Jonathan Harker ’ Journal CHAPTER IV . Jonathan Harker ’ Journal CHAPTER V. Letters—Lucy Mina CHAPTER VI . Mina Murray ’ Journal CHAPTER VII . Cutting “ Dailygraph , ” 8 August CHAPTER VIII . Mina Murray ’ Journal CHAPTER IX . Mina Murray ’ Journal CHAPTER X. Mina Murray ’ Journal CHAPTER XI . Lucy Westenra ’ Diary CHAPTER XII . Dr. Seward ’ Diary CHAPTER XIII . Dr. Seward ’ Diary CHAPTER XIV . Mina Harker ’ Journal CHAPTER XV . Dr. Seward ’ Diary CHAPTER XVI . Dr. Seward ’ Diary CHAPTER XVII . Dr. Seward ’ Diary CHAPTER XVIII . Dr. Seward ’ Diary CHAPTER XIX . Jonathan Harker ’ Journal CHAPTER XX . Jonathan Harker ’ Journal CHAPTER XXI . Dr. Seward ’ Diary CHAPTER XXII . Jonathan Harker ’ Journal CHAPTER XXIII . Dr. Seward ’ Diary CHAPTER XXIV . Dr. Seward ’ Phonograph Diary , spoken Van Helsing CHAPTER XXV . Dr. Seward ’ Diary CHAPTER XXVI . Dr. Seward ’ Diary CHAPTER XXVII . Mina Harker ’ Journal papers placed sequence made manifest reading . needless matters eliminated , history almost variance possibilities later-day belief may stand forth simple fact . throughout statement past things wherein memory may err , records chosen exactly contemporary , given standpoints within range knowledge made . DRACULA CHAPTER JONATHAN HARKER ’ JOURNAL ( _Kept shorthand._ ) _3 May . Bistritz._ -- Left Munich 8:35 P. M. , 1st May , arriving Vienna early next morning ; arrived 6:46 , train hour late . Buda-Pesth seems wonderful place , glimpse got train little could walk streets . feared go far station , arrived late would start near correct time possible . impression leaving West entering East ; western splendid bridges Danube , noble width depth , took us among traditions Turkish rule . left pretty good time , came nightfall Klausenburgh . stopped night Hotel Royale . dinner , rather supper , chicken done way red pepper , good thirsty . ( _Mem._ , get recipe Mina . ) asked waiter , said called “ paprika hendl , ” , national dish , able get anywhere along Carpathians . found smattering German useful ; indeed , ’ know able get without . time disposal London , visited British Museum , made search among books maps library regarding Transylvania ; struck foreknowledge country could hardly fail importance dealing nobleman country . find district named extreme east country , borders three states , Transylvania , Moldavia Bukovina , midst Carpathian mountains ; one wildest least known portions Europe . able light map work giving exact locality Castle Dracula , maps country yet compare Ordnance Survey maps ; found Bistritz , post town named Count Dracula , fairly well-known place . shall enter notes , may refresh memory talk travels Mina . population Transylvania four distinct nationalities : Saxons South , mixed Wallachs , descendants Dacians ; Magyars West , Szekelys East North . going among latter , claim descended Attila Huns . may , Magyars conquered country eleventh century found Huns settled . read every known superstition world gathered horseshoe Carpathians , centre sort imaginative whirlpool ; stay may interesting . ( _Mem._ , must ask Count . ) sleep well , though bed comfortable eno ...

# %%
# !python -m spacy download en_core_web_md

# %%
nlp = spacy.load("en_core_web_md")

# %%
# lemmatizer = nlp.get_pipe("lemmatizer")

# %%
book = nlp(preprocessed_text)

# %%
f_book = nlp(filtered_text)

# %%
labels = [x.label_ for x in book.ents]
Counter(labels) # need to focus on PERSON and GPE labels
# Out:
# Counter({'PERSON': 2133,
#          'CARDINAL': 575,
#          'TIME': 496,
#          'ORG': 478,
#          'DATE': 445,
#          'GPE': 352,
#          'ORDINAL': 164,
#          'NORP': 148,
#          'LOC': 112,
#          'FAC': 73,
#          'PRODUCT': 36,
#          'WORK_OF_ART': 24,
#          'QUANTITY': 16,
#          'LAW': 13,
#          'LANGUAGE': 12,
#          'EVENT': 5,
#          'MONEY': 1})

# %%
f_labels = [x.label_ for x in f_book.ents]
Counter(f_labels)
# Out:
# Counter({'PERSON': 2195,
#          'CARDINAL': 630,
#          'DATE': 488,
#          'ORG': 396,
#          'TIME': 372,
#          'GPE': 337,
#          'ORDINAL': 162,
#          'NORP': 117,
#          'LOC': 76,
#          'WORK_OF_ART': 67,
#          'FAC': 42,
#          'QUANTITY': 16,
#          'LANGUAGE': 15,
#          'PRODUCT': 12,
#          'LAW': 7,
#          'MONEY': 6,
#          'EVENT': 2,
#          'PERCENT': 1})

# %%
book.ents[1].text, book.ents[1].label_, book.ents[1].start, book.ents[1].end
# Out:
# ('Dracula', 'PERSON', 5, 6)

# %%
for token in book[:10]:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# The the DET DT det Xxx True True
# Project Project PROPN NNP compound Xxxxx True False
# Gutenberg Gutenberg PROPN NNP compound Xxxxx True False
# eBook eBook PROPN NNP ROOT xXxxx True False
# of of ADP IN prep xx True True
# Dracula Dracula PROPN NNP pobj Xxxxx True False
# This this DET DT det Xxxx True True
# ebook ebook NOUN NN nsubj xxxx True False
# is be AUX VBZ ROOT xx True True
# for for ADP IN prep xxx True True

# %%
items = [x.text for x in book.ents]
Counter(items).most_common(30)
# Out:
# [('Van Helsing', 257),
#  ('Lucy', 195),
#  ('one', 151),
#  ('Jonathan', 137),
#  ('Mina', 136),
#  ('first', 117),
#  ('Arthur', 112),
#  ('two', 104),
#  ('tonight', 72),
#  ('Lucys', 72),
#  ('Godalming', 72),
#  ('Seward', 64),
#  ('Harker', 63),
#  ('London', 57),
#  ('Project Gutenberg', 52),
#  ('John', 51),
#  ('Quincey', 46),
#  ('today', 44),
#  ('Morris', 42),
#  ('Renfield', 38),
#  ('Sewards Diary', 35),
#  ('three', 32),
#  ('Whitby', 30),
#  ('One', 29),
#  ('tomorrow', 27),
#  ('last night', 26),
#  ('yesterday', 23),
#  ('Quincey Morris', 23),
#  ('UnDead', 23),
#  ('Mrs Harker', 23)]

# %%
f_items = [x.text for x in f_book.ents]
Counter(f_items).most_common(30)
# Out:
# [('Van Helsing', 297),
#  ('Lucy', 276),
#  ('one', 244),
#  ('Mina', 168),
#  ('Jonathan', 158),
#  ('Arthur', 127),
#  ('first', 117),
#  ('Harker', 106),
#  ('two', 104),
#  ('Seward', 72),
#  ('Godalming', 64),
#  ('London', 61),
#  ('night', 61),
#  ('John', 54),
#  ('Renfield', 46),
#  ('Morris', 44),
#  ('morning', 43),
#  ('half', 42),
#  ('morrow', 41),
#  ('Quincey', 40),
#  ('Project Gutenberg™', 40),
#  ('three', 35),
#  ('One', 33),
#  ('Un-Dead', 33),
#  ('last night', 31),
#  ('Whitby', 29),
#  ('Seward ’ Diary', 27),
#  ('yesterday', 25),
#  ('Dracula', 24),
#  ('Carfax', 23)]

# %%
book.ents[21]
# Out:
# Sewards Diary

# %%
def get_person_counts(doc):
    counts = {}

    for ent in doc.ents:
        if ent.label_ == 'PERSON':
            if ent.text not in counts.keys():
                counts[ent.text] = {}
                counts[ent.text]['count'] = 1
                counts[ent.text]['position'] = [(ent.start, ent.end)]
            else:
                counts[ent.text]['count'] += 1
                counts[ent.text]['position'].append((ent.start, ent.end))    

    return sorted(counts.items(), key=lambda x: x[1]['count'], reverse=True)

# %%
person_counts = get_person_counts(book)

# %%
preprocessed_text.split()[:10]
# Out:
# ['The',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'Dracula',
#  'This',
#  'ebook',
#  'is',
#  'for']

# %%
person_counts[8]
# Out:
# ('Seward',
#  {'count': 65,
#   'position': [(29168, 29169),
#    (54746, 54747),
#    (55048, 55049),
#    (55090, 55091),
#    (56121, 56122),
#    (56364, 56365),
#    (58594, 58595),
#    (62997, 62998),
#    (64194, 64195),
#    (70402, 70403),
#    (73513, 73514),
#    (102558, 102559),
#    (107848, 107849),
#    (108689, 108690),
#    (109813, 109814),
#    (109947, 109948),
#    (110252, 110253),
#    (110350, 110351),
#    (112462, 112463),
#    (114005, 114006),
#    (114357, 114358),
#    (114462, 114463),
#    (114491, 114492),
#    (114646, 114647),
#    (116112, 116113),
#    (116154, 116155),
#    (116169, 116170),
#    (117064, 117065),
#    (120372, 120373),
#    (120587, 120588),
#    (120656, 120657),
#    (121046, 121047),
#    (121577, 121578),
#    (121954, 121955),
#    (122295, 122296),
#    (122950, 122951),
#    (124201, 124202),
#    (127979, 127980),
#    (128342, 128343),
#    (129556, 129557),
#    (132944, 132945),
#    (134209, 134210),
#    (139713, 139714),
#    (140310, 140311),
#    (142505, 142506),
#    (142673, 142674),
#    (142695, 142696),
#    (142745, 142746),
#    (142906, 142907),
#    (153805, 153806),
#    (153890, 153891),
#    (156091, 156092),
#    (161857, 161858),
#    (165472, 165473),
#    (171660, 171661),
#    (174957, 174958),
#    (176129, 176130),
#    (176669, 176670),
#    (177466, 177467),
#    (182402, 182403),
#    (185129, 185130),
#    (185753, 185754),
#    (186446, 186447),
#    (187249, 187250),
#    (187318, 187319)]})

# %%
def get_location_counts(person_counts, preprocessed_text, nlp):

    for entry in person_counts:
        entry[1]['associated_places'] = {}
        for pos in entry[1]['position']:
            start, end = pos
            section_of_text = preprocessed_text[start-100:end+100]
            doc = nlp(section_of_text)

            for ent in doc.ents:
                if ent.label_ == 'GPE':
                    if ent.text not in entry[1]['associated_places'].keys():
                        entry[1]['associated_places'][ent.text] = 1
                    else:
                        entry[1]['associated_places'][ent.text] += 1
    
    return person_counts

# %%
full_counts = get_location_counts(person_counts, preprocessed_text, nlp)

# %%
full_counts[21]
# Out:
# ('Harkers',
#  {'count': 14,
#   'position': [(107567, 107568),
#    (109182, 109183),
#    (114773, 114774),
#    (115376, 115377),
#    (138936, 138937),
#    (140978, 140979),
#    (150163, 150164),
#    (159105, 159106),
#    (159235, 159236),
#    (159391, 159392),
#    (164539, 164540),
#    (166169, 166170),
#    (166531, 166532),
#    (171281, 171282)],
#   'associated_places': {'Korea': 1}})

# %%
full_counts[21]
# Out:
# ('Harkers',
#  {'count': 14,
#   'position': [(107567, 107568),
#    (109182, 109183),
#    (114773, 114774),
#    (115376, 115377),
#    (138936, 138937),
#    (140978, 140979),
#    (150163, 150164),
#    (159105, 159106),
#    (159235, 159236),
#    (159391, 159392),
#    (164539, 164540),
#    (166169, 166170),
#    (166531, 166532),
#    (171281, 171282)],
#   'associated_places': {'Korea': 1}})

# %%
def order_associated_places(full_counts):
    for person in full_counts:
        person["associated_places"] = sorted(person["associated_places"], key=lambda x: x["count"], reverse=True)

    return full_counts

def format_list(full_counts):
    people = []

    for i, entry in enumerate(full_counts):
        people.append({})
        people[i]["name"] = entry[0]
        people[i]["count"] = entry[1]['count']
        people[i]["associated_places"] = []

        for j, entry_ in enumerate(entry[1]['associated_places'].items()):
            place = {}
            k, v = entry_
            place['name'] = k
            place['count'] = v
            people[i]["associated_places"].append(place)
    people = order_associated_places(people)
    return people

# %%
for i, entry in enumerate(full_counts[21][1]['associated_places'].items()):
    print(entry)
# Out:
# ('Korea', 1)

# %%
format_list(full_counts)
# Out:
# [{'name': 'Van Helsing',
#   'count': 279,
#   'associated_places': [{'name': 'London', 'count': 4},
#    {'name': 'Whitby', 'count': 3},
#    {'name': 'ay', 'count': 2},
#    {'name': 'Yorkshire', 'count': 1},
#    {'name': 'Transylvania', 'count': 1},
#    {'name': 'Iceland', 'count': 1},
#    {'name': 'Turkey', 'count': 1},
#    {'name': 'Newcastle', 'count': 1},
#    {'name': 'Durham', 'count': 1},
#    {'name': 'Harwich', 'count': 1},
#    {'name': 'Dover', 'count': 1},
#    {'name': 'Titicaca', 'count': 1},
#    {'name': 'York', 'count': 1},
#    {'name': 'Leeds', 'count': 1},
#    {'name': 'Duns', 'count': 1},
#    {'name': 'rrives', 'count': 1},
#    {'name': 'Scarborough', 'count': 1},
#    {'name': 'ger', 'count': 1}]},
#  {'name': 'Lucy',
#   'count': 198,
#   'associated_places': [{'name': 'London', 'count': 8},
#    {'name': 'England', 'count': 3},
#    {'name': 'Transylvania', 'count': 2},
#    {'name': 'Carfax', 'count': 1},
#    {'name': 'Turkey', 'count': 1},
#    {'name': 'tunn', 'count': 1},
#    {'name': 'st', 'count': 1}]},
#  {'name': 'Mina',
#   'count': 161,
#   'associated_places': [{'name': 'Whitby', 'count': 4},
#    {'name': 'London', 'count': 3},
#    {'name': 'Bukovina', 'count': 2},
#    {'name': 'bairns', 'count': 2},
#    {'name': 'June._--He', 'count': 2},
#    {'name': 'GARDEN CITY', 'count': 1},
#    {'name': 'N.Y.', 'count': 1},
#    {'name': 'disappe', 'count': 1},
#    {'name': 'Titicaca', 'count': 1},
#    {'name': 'Nuremberg', 'count': 1},
#    {'name': 'York', 'count': 1},
#    {'name': 'Leeds', 'count': 1},
#    {'name': 'skeer', 'count': 1},
#    {'name': 'Varna', 'count': 1},
#    {'name': 'Dardanelles', 'count': 1}]},
#  {'name': 'Jonathan',
#   'count': 150,
#   'associated_places': [{'name': 'London', 'count': 5},
#    {'name': 'nethermost', 'count': 1},
#    {'name': 'Wel', 'count': 1},
#    {'name': 'Varna', 'count': 1},
#    {'name': 'Whitby', 'count': 1}]},
#  {'name': 'Arthur',
#   'count': 119,
#   'associated_places': [{'name': 'London', 'count': 3},
#    {'name': 'England', 'count': 1},
#    {'name': 'hea', 'count': 1},
#    {'name': 'Whitby', 'count': 1},
#    {'name': 'Varna', 'count': 1}]},
#  {'name': 'Harker',
#   'count': 84,
#   'associated_places': [{'name': 'Whitby', 'count': 2},
#    {'name': 'Rig Mill', 'count': 1},
#    {'name': 'Runswick', 'count': 1}]},
#  {'name': 'Lucys',
#   'count': 74,
#   'associated_places': [{'name': 'London', 'count': 4},
#    {'name': 'England', 'count': 1},
#    {'name': 'Transylvania', 'count': 1},
#    {'name': 'Turkey', 'count': 1},
#    {'name': 'slee', 'count': 1}]},
#  {'name': 'Godalming',
#   'count': 73,
#   'associated_places': [{'name': 'bairns', 'count': 1},
#    {'name': 'acca', 'count': 1},
#    {'name': 'Andres', 'count': 1},
#    {'name': 'Whitby', 'count': 1}]},
#  {'name': 'Seward',
#   'count': 65,
#   'associated_places': [{'name': 'London', 'count': 2},
#    {'name': 'Nuremberg', 'count': 1},
#    {'name': 'Whitby', 'count': 1}]},
#  {'name': 'John',
#   'count': 61,
#   'associated_places': [{'name': 'London', 'count': 1},
#    {'name': 'Whitby', 'count': 1}]},
#  {'name': 'Quincey',
#   'count': 51,
#   'associated_places': [{'name': 'London', 'count': 1},
#    {'name': 'Titicaca', 'count': 1},
#    {'name': 'Whitby', 'count': 1},
#    {'name': 'bairns', 'count': 1}]},
#  {'name': 'Morris',
#   'count': 44,
#   'associated_places': [{'name': 'Whitby', 'count': 2},
#    {'name': 'nethermost', 'count': 1},
#    {'name': 'Duns', 'count': 1},
#    {'name': 'Rig Mill', 'count': 1},
#    {'name': 'Runswick', 'count': 1},
#    {'name': 'Scarborough', 'count': 1}]},
#  {'name': 'Sewards Diary',
#   'count': 36,
#   'associated_places': [{'name': 'the United States', 'count': 9},
#    {'name': 'u', 'count': 1},
#    {'name': 'ay', 'count': 1},
#    {'name': 'London', 'count': 1},
#    {'name': 'Whitby', 'count': 1}]},
#  {'name': 'Renfield', 'count': 36, 'associated_places': []},
#  {'name': 'Dracula',
#   'count': 21,
#   'associated_places': [{'name': 'America', 'count': 1},
#    {'name': 'GARDEN CITY', 'count': 1},
#    {'name': 'N.Y.', 'count': 1}]},
#  {'name': 'Van Helsings',
#   'count': 21,
#   'associated_places': [{'name': 'Transylvania', 'count': 1},
#    {'name': 'London', 'count': 1},
#    {'name': 'Andres', 'count': 1}]},
#  {'name': 'Jonathans',
#   'count': 18,
#   'associated_places': [{'name': 'Varna', 'count': 1}]},
#  {'name': 'Quincey Morris', 'count': 18, 'associated_places': []},
#  {'name': 'Westenra',
#   'count': 17,
#   'associated_places': [{'name': 'England', 'count': 1},
#    {'name': 'Turkey', 'count': 1}]},
#  {'name': 'Czarina Catherine', 'count': 17, 'associated_places': []},
#  {'name': 'Hawkins', 'count': 16, 'associated_places': []},
#  {'name': 'Harkers',
#   'count': 14,
#   'associated_places': [{'name': 'Korea', 'count': 1}]},
#  {'name': 'Lucy Westenra',
#   'count': 12,
#   'associated_places': [{'name': 'London', 'count': 2},
#    {'name': 'hrough', 'count': 1}]},
#  {'name': 'Arthurs', 'count': 10, 'associated_places': []},
#  {'name': 'September._--I', 'count': 10, 'associated_places': []},
#  {'name': 'Skinsky', 'count': 10, 'associated_places': []},
#  {'name': 'Arthur Holmwood', 'count': 9, 'associated_places': []},
#  {'name': 'Sewards', 'count': 9, 'associated_places': []},
#  {'name': 'Project Gutenberg', 'count': 9, 'associated_places': []},
#  {'name': 'Jonathan Harker',
#   'count': 8,
#   'associated_places': [{'name': 'Korea', 'count': 1}]},
#  {'name': 'Jack',
#   'count': 8,
#   'associated_places': [{'name': 'Whitby', 'count': 1},
#    {'name': 'Varna', 'count': 1},
#    {'name': 'London', 'count': 1}]},
#  {'name': 'Renfields',
#   'count': 7,
#   'associated_places': [{'name': 'china', 'count': 1},
#    {'name': 'Whitby', 'count': 1}]},
#  {'name': 'wolf',
#   'count': 7,
#   'associated_places': [{'name': 'London', 'count': 1}]},
#  {'name': 'Mem', 'count': 6, 'associated_places': []},
#  {'name': 'Peter Hawkins', 'count': 6, 'associated_places': []},
#  {'name': 'Holmwood', 'count': 6, 'associated_places': []},
#  {'name': 'John Seward', 'count': 6, 'associated_places': []},
#  {'name': 'Swales', 'count': 6, 'associated_places': []},
#  {'name': 'God', 'count': 6, 'associated_places': []},
#  {'name': 'Mina Murray', 'count': 5, 'associated_places': []},
#  {'name': 'Mina Harker', 'count': 5, 'associated_places': []},
#  {'name': 'Draculas', 'count': 5, 'associated_places': []},
#  {'name': 'Fundu',
#   'count': 5,
#   'associated_places': [{'name': 'u', 'count': 1}]},
#  {'name': 'Mary', 'count': 4, 'associated_places': []},
#  {'name': 'Exeter', 'count': 4, 'associated_places': []},
#  {'name': 'Lucy Westenras Diary',
#   'count': 4,
#   'associated_places': [{'name': 'Iceland', 'count': 1},
#    {'name': 'Turkey', 'count': 1}]},
#  {'name': 'Miss Westenra', 'count': 4, 'associated_places': []},
#  {'name': 'Art',
#   'count': 4,
#   'associated_places': [{'name': 'Whitby', 'count': 1}]},
#  {'name': 'Lor',
#   'count': 4,
#   'associated_places': [{'name': 'Turkey', 'count': 1}]},
#  {'name': 'Jonathan Harkers Journal',
#   'count': 4,
#   'associated_places': [{'name': 'England', 'count': 1},
#    {'name': 'Whitby', 'count': 1}]},
#  {'name': 'Sam', 'count': 4, 'associated_places': []},
#  {'name': 'Bram Stoker',
#   'count': 3,
#   'associated_places': [{'name': 'the United States', 'count': 3}]},
#  {'name': 'DRACULA',
#   'count': 3,
#   'associated_places': [{'name': 'the United States', 'count': 1}]},
#  {'name': 'LUCY', 'count': 3, 'associated_places': []},
#  {'name': 'Quincey P. Morris', 'count': 3, 'associated_places': []},
#  {'name': 'Morriss', 'count': 3, 'associated_places': []},
#  {'name': 'Jack Seward', 'count': 3, 'associated_places': []},
#  {'name': 'Ye', 'count': 3, 'associated_places': []},
#  {'name': 'Geordie', 'count': 3, 'associated_places': []},
#  {'name': 'Mina Murrays Journal', 'count': 3, 'associated_places': []},
#  {'name': 'Castle Dracula', 'count': 3, 'associated_places': []},
#  {'name': 'Demeter', 'count': 3, 'associated_places': []},
#  {'name': 'Ste', 'count': 3, 'associated_places': []},
#  {'name': 'Lucy,--', 'count': 3, 'associated_places': []},
#  {'name': 'Sister Agatha',
#   'count': 3,
#   'associated_places': [{'name': 'Exeter', 'count': 1}]},
#  {'name': 'Westenras', 'count': 3, 'associated_places': []},
#  {'name': 'Abraham Van Helsing', 'count': 3, 'associated_places': []},
#  {'name': 'Telegram',
#   'count': 3,
#   'associated_places': [{'name': 'starti', 'count': 1}]},
#  {'name': 'Thomas', 'count': 3, 'associated_places': []},
#  {'name': 'Thomas Snelling', 'count': 3, 'associated_places': []},
#  {'name': 'Hampstead Heath', 'count': 3, 'associated_places': []},
#  {'name': 'Vincent', 'count': 3, 'associated_places': []},
#  {'name': 'Billington',
#   'count': 3,
#   'associated_places': [{'name': 'England', 'count': 1}]},
#  {'name': 'Bloxam', 'count': 3, 'associated_places': []},
#  {'name': 'Quinceys', 'count': 3, 'associated_places': []},
#  {'name': 'Herr', 'count': 2, 'associated_places': []},
#  {'name': 'Thor', 'count': 2, 'associated_places': []},
#  {'name': 'Bah', 'count': 2, 'associated_places': []},
#  {'name': 'Hawkinss', 'count': 2, 'associated_places': []},
#  {'name': 'Shakespeare', 'count': 2, 'associated_places': []},
#  {'name': 'ajar', 'count': 2, 'associated_places': []},
#  {'name': 'Faugh', 'count': 2, 'associated_places': []},
#  {'name': 'Art,--', 'count': 2, 'associated_places': []},
#  {'name': 'John Paxton', 'count': 2, 'associated_places': []},
#  {'name': 'Mulgrave Woods', 'count': 2, 'associated_places': []},
#  {'name': 'Robin Hoods Bay', 'count': 2, 'associated_places': []},
#  {'name': 'Carter',
#   'count': 2,
#   'associated_places': [{'name': 'Transylvania', 'count': 2},
#    {'name': 'England', 'count': 1}]},
#  {'name': 'Sirs,--',
#   'count': 2,
#   'associated_places': [{'name': 'Transylvania', 'count': 2},
#    {'name': 'England', 'count': 1}]},
#  {'name': 'Sirs', 'count': 2, 'associated_places': []},
#  {'name': 'Wilhelmina',
#   'count': 2,
#   'associated_places': [{'name': 'Exeter', 'count': 1}]},
#  {'name': 'JOHN', 'count': 2, 'associated_places': []},
#  {'name': 'M. D.', 'count': 2, 'associated_places': []},
#  {'name': 'I.', 'count': 2, 'associated_places': []},
#  {'name': 'arsk',
#   'count': 2,
#   'associated_places': [{'name': 'Turkey', 'count': 1}]},
#  {'name': 'warnt', 'count': 2, 'associated_places': []},
#  {'name': 'Bilder', 'count': 2, 'associated_places': []},
#  {'name': 'Night._--I',
#   'count': 2,
#   'associated_places': [{'name': 'London', 'count': 2}]},
#  {'name': 'M. D._', 'count': 2, 'associated_places': []},
#  {'name': 'speak:--', 'count': 2, 'associated_places': []},
#  {'name': 'Friend John', 'count': 2, 'associated_places': []},
#  {'name': 'Charcot', 'count': 2, 'associated_places': []},
#  {'name': 'Later._--Lord Godalming', 'count': 2, 'associated_places': []},
#  {'name': 'Arminius', 'count': 2, 'associated_places': []},
#  {'name': 'quickly:--', 'count': 2, 'associated_places': []},
#  {'name': 'Yus', 'count': 2, 'associated_places': []},
#  {'name': 'Godalmings', 'count': 2, 'associated_places': []},
#  {'name': 'Enoch', 'count': 2, 'associated_places': []},
#  {'name': 'Rufus Smith', 'count': 2, 'associated_places': []},
#  {'name': 'Deil', 'count': 2, 'associated_places': []},
#  {'name': 'Immanuel Hildesheim',
#   'count': 2,
#   'associated_places': [{'name': 'Whit', 'count': 1}]},
#  {'name': 'Petrof Skinsky',
#   'count': 2,
#   'associated_places': [{'name': 'clun', 'count': 1}]},
#  {'name': 'Sereth', 'count': 2, 'associated_places': []},
#  {'name': 'AGREE', 'count': 2, 'associated_places': []},
#  {'name': 'Mina CHAPTER VI', 'count': 1, 'associated_places': []},
#  {'name': 'Lucy Westenras Diary CHAPTER XII',
#   'count': 1,
#   'associated_places': [{'name': 'Unit', 'count': 1}]},
#  {'name': 'Sewards Phonograph Diary',
#   'count': 1,
#   'associated_places': [{'name': 'the United States', 'count': 1}]},
#  {'name': 'Van Helsing CHAPTER XXV',
#   'count': 1,
#   'associated_places': [{'name': 'the United States', 'count': 1}]},
#  {'name': 'JONATHAN',
#   'count': 1,
#   'associated_places': [{'name': 'the United States', 'count': 1}]},
#  {'name': 'Bistritz._--Left Munich',
#   'count': 1,
#   'associated_places': [{'name': 'States', 'count': 1}]},
#  {'name': 'paprika hendl',
#   'count': 1,
#   'associated_places': [{'name': 'Unite', 'count': 1}]},
#  {'name': 'Wallachs',
#   'count': 1,
#   'associated_places': [{'name': 'GARDEN CITY', 'count': 1},
#    {'name': 'N.Y.', 'count': 1}]},
#  {'name': 'Szekelys',
#   'count': 1,
#   'associated_places': [{'name': 'GARDEN CITY', 'count': 1},
#    {'name': 'N.Y.', 'count': 1}]},
#  {'name': 'Count Dracula', 'count': 1, 'associated_places': []},
#  {'name': 'gotza', 'count': 1, 'associated_places': []},
#  {'name': 'Borgo Prund', 'count': 1, 'associated_places': []},
#  {'name': 'Todten reiten schnell--', 'count': 1, 'associated_places': []},
#  {'name': 'German:-- The night', 'count': 1, 'associated_places': []},
#  {'name': 'mein Herr', 'count': 1, 'associated_places': []},
#  {'name': 'slivovitz', 'count': 1, 'associated_places': []},
#  {'name': 'me.--D.',
#   'count': 1,
#   'associated_places': [{'name': 'London', 'count': 1}]},
#  {'name': 'Harker Jonathan', 'count': 1, 'associated_places': []},
#  {'name': 'Quatre Face', 'count': 1, 'associated_places': []},
#  {'name': 'Good-morning', 'count': 1, 'associated_places': []},
#  {'name': 'Wodin', 'count': 1, 'associated_places': []},
#  {'name': 'Arpad', 'count': 1, 'associated_places': []},
#  {'name': 'Honfoglalas', 'count': 1, 'associated_places': []},
#  {'name': 'Wallach', 'count': 1, 'associated_places': []},
#  {'name': 'Voivode',
#   'count': 1,
#   'associated_places': [{'name': 'st', 'count': 1}]},
#  {'name': 'Hapsburgs', 'count': 1, 'associated_places': []},
#  {'name': 'resistless way:--', 'count': 1, 'associated_places': []},
#  {'name': 'Samuel F. Billington', 'count': 1, 'associated_places': []},
#  {'name': 'Herr Leutner', 'count': 1, 'associated_places': []},
#  {'name': 'moth', 'count': 1, 'associated_places': []},
#  {'name': 'Hamlet', 'count': 1, 'associated_places': []},
#  {'name': 'Sweet', 'count': 1, 'associated_places': []},
#  {'name': 'menace:-- Monster', 'count': 1, 'associated_places': []},
#  {'name': 'Judas', 'count': 1, 'associated_places': []},
#  {'name': 'morning._--These',
#   'count': 1,
#   'associated_places': [{'name': 'Bukovina', 'count': 1}]},
#  {'name': 'Lucy,-- Forgive', 'count': 1, 'associated_places': []},
#  {'name': 'Desdemona', 'count': 1, 'associated_places': []},
#  {'name': 'Omnia Rom venalia sunt', 'count': 1, 'associated_places': []},
#  {'name': 'therefore-- R. M. Renfield', 'count': 1, 'associated_places': []},
#  {'name': 'QUINCEY P. MORRIS', 'count': 1, 'associated_places': []},
#  {'name': 'Marmion', 'count': 1, 'associated_places': []},
#  {'name': 'Waterloo', 'count': 1, 'associated_places': []},
#  {'name': 'crammle aboon', 'count': 1, 'associated_places': []},
#  {'name': 'Oracle', 'count': 1, 'associated_places': []},
#  {'name': 'snod', 'count': 1, 'associated_places': []},
#  {'name': 'Edward Spencelagh', 'count': 1, 'associated_places': []},
#  {'name': 'This Braithwaite Lowrey', 'count': 1, 'associated_places': []},
#  {'name': 'Andrew Woodhouse', 'count': 1, 'associated_places': []},
#  {'name': 'Cape Farewell', 'count': 1, 'associated_places': []},
#  {'name': 'John Rawlings', 'count': 1, 'associated_places': []},
#  {'name': 'George Canon', 'count': 1, 'associated_places': []},
#  {'name': 'nt gawm', 'count': 1, 'associated_places': []},
#  {'name': 'Gabriel', 'count': 1, 'associated_places': []},
#  {'name': 'July._--Visited Renfield', 'count': 1, 'associated_places': []},
#  {'name': 'Ferriers', 'count': 1, 'associated_places': []},
#  {'name': 'grey earthy rock', 'count': 1, 'associated_places': []},
#  {'name': 'the Aud Man', 'count': 1, 'associated_places': []},
#  {'name': 'whettin', 'count': 1, 'associated_places': []},
#  {'name': 'dooal', 'count': 1, 'associated_places': []},
#  {'name': 'Emma', 'count': 1, 'associated_places': []},
#  {'name': 'the R. A.', 'count': 1, 'associated_places': []},
#  {'name': 'R. I.', 'count': 1, 'associated_places': []},
#  {'name': 'lanthorns', 'count': 1, 'associated_places': []},
#  {'name': 'dictu_', 'count': 1, 'associated_places': []},
#  {'name': 'J. M. Caffyn', 'count': 1, 'associated_places': []},
#  {'name': 'S. F. Billington', 'count': 1, 'associated_places': []},
#  {'name': 'cum grano', 'count': 1, 'associated_places': []},
#  {'name': 'flagboat', 'count': 1, 'associated_places': []},
#  {'name': 'Petrofsky', 'count': 1, 'associated_places': []},
#  {'name': 'Abramoff', 'count': 1, 'associated_places': []},
#  {'name': 'Olgaren', 'count': 1, 'associated_places': []},
#  {'name': 'July_.--Rough', 'count': 1, 'associated_places': []},
#  {'name': 'Mate', 'count': 1, 'associated_places': []},
#  {'name': 'noon._--All', 'count': 1, 'associated_places': []},
#  {'name': 'Spohr', 'count': 1, 'associated_places': []},
#  {'name': 'Samuel F. Billington & Son',
#   'count': 1,
#   'associated_places': [{'name': 'Transylvania', 'count': 2},
#    {'name': 'England', 'count': 1}]},
#  {'name': 'Wilhelmina Murray', 'count': 1, 'associated_places': []},
#  {'name': 'St. Joseph', 'count': 1, 'associated_places': []},
#  {'name': 'Jack Sheppard', 'count': 1, 'associated_places': []},
#  {'name': 'Buda-Pesth', 'count': 1, 'associated_places': []},
#  {'name': 'Hull', 'count': 1, 'associated_places': []},
#  {'name': 'Mina,-- Oceans', 'count': 1, 'associated_places': []},
#  {'name': 'P. P. S.--We', 'count': 1, 'associated_places': []},
#  {'name': 'Hillingham', 'count': 1, 'associated_places': []},
#  {'name': 'Albemarle Hotel', 'count': 1, 'associated_places': []},
#  {'name': 'Jack,--', 'count': 1, 'associated_places': []},
#  {'name': 'fellow,--', 'count': 1, 'associated_places': []},
#  {'name': 'Murray',
#   'count': 1,
#   'associated_places': [{'name': 'Yorkshire', 'count': 1}]},
#  {'name': 'D. Ph.', 'count': 1, 'associated_places': []},
#  {'name': 'Art,-- Van Helsing', 'count': 1, 'associated_places': []},
#  {'name': 'chalkily pale', 'count': 1, 'associated_places': []},
#  {'name': 'indrawn breath', 'count': 1, 'associated_places': []},
#  {'name': 'Gott', 'count': 1, 'associated_places': []},
#  {'name': 'Vanderpool', 'count': 1, 'associated_places': []},
#  {'name': 'ho', 'count': 1, 'associated_places': []},
#  {'name': 'Ophelia',
#   'count': 1,
#   'associated_places': [{'name': 'ay', 'count': 1}]},
#  {'name': 'virgin crants',
#   'count': 1,
#   'associated_places': [{'name': 'ay', 'count': 1}]},
#  {'name': 'maiden strewments',
#   'count': 1,
#   'associated_places': [{'name': 'ay', 'count': 1}]},
#  {'name': 'Thomas Bilder', 'count': 1, 'associated_places': []},
#  {'name': 'Tom', 'count': 1, 'associated_places': []},
#  {'name': 'wolf isself', 'count': 1, 'associated_places': []},
#  {'name': 'owlin', 'count': 1, 'associated_places': []},
#  {'name': 'Keeper', 'count': 1, 'associated_places': []},
#  {'name': 'I. Bersicker', 'count': 1, 'associated_places': []},
#  {'name': 'larst', 'count': 1, 'associated_places': []},
#  {'name': 'The gardner wot', 'count': 1, 'associated_places': []},
#  {'name': 'Bilders', 'count': 1, 'associated_places': []},
#  {'name': 'September._--Do', 'count': 1, 'associated_places': []},
#  {'name': 'grey wolf',
#   'count': 1,
#   'associated_places': [{'name': 'Newcastle', 'count': 1},
#    {'name': 'Durham', 'count': 1},
#    {'name': 'Harwich', 'count': 1},
#    {'name': 'Dover', 'count': 1}]},
#  {'name': 'Patrick Hennessey', 'count': 1, 'associated_places': []},
#  {'name': 'M. R. C. S. L. K. Q. C. P. I.',
#   'count': 1,
#   'associated_places': []},
#  {'name': 'Hardy', 'count': 1, 'associated_places': []},
#  {'name': 'drouth', 'count': 1, 'associated_places': []},
#  {'name': 'follows:--Jack Smollet', 'count': 1, 'associated_places': []},
#  {'name': 'Yours', 'count': 1, 'associated_places': []},
#  {'name': 'Mein Gott!', 'count': 1, 'associated_places': []},
#  {'name': 'Marquand', 'count': 1, 'associated_places': []},
#  {'name': 'Lord----', 'count': 1, 'associated_places': []},
#  {'name': 'Jacks', 'count': 1, 'associated_places': []},
#  {'name': 'Thud', 'count': 1, 'associated_places': []},
#  {'name': 'Ho', 'count': 1, 'associated_places': []},
#  {'name': 'said:-- Friend', 'count': 1, 'associated_places': []},
#  {'name': 'FINIS', 'count': 1, 'associated_places': []},
#  {'name': 'navely', 'count': 1, 'associated_places': []},
#  {'name': 'Ellen Terry', 'count': 1, 'associated_places': []},
#  {'name': 'HORROR', 'count': 1, 'associated_places': []},
#  {'name': 'Lucy Westenras', 'count': 1, 'associated_places': []},
#  {'name': 'Husband Jonathan', 'count': 1, 'associated_places': []},
#  {'name': 'Van Helsing,--', 'count': 1, 'associated_places': []},
#  {'name': 'Launceston', 'count': 1, 'associated_places': []},
#  {'name': 'choky', 'count': 1, 'associated_places': []},
#  {'name': 'Mein Gott', 'count': 1, 'associated_places': []},
#  {'name': 'Westminster Gazette', 'count': 1, 'associated_places': []},
#  {'name': 'hypnotism----', 'count': 1, 'associated_places': []},
#  {'name': 'Byron', 'count': 1, 'associated_places': []},
#  {'name': 'Red Riding Hood', 'count': 1, 'associated_places': []},
#  {'name': 'garlic', 'count': 1, 'associated_places': []},
#  {'name': 'John,--', 'count': 1, 'associated_places': []},
#  {'name': 'Quincey Morris:-- Professor', 'count': 1, 'associated_places': []},
#  {'name': 'Van Helsing:--', 'count': 1, 'associated_places': []},
#  {'name': 'said:-- Brave', 'count': 1, 'associated_places': []},
#  {'name': 'knell', 'count': 1, 'associated_places': []},
#  {'name': 'but----', 'count': 1, 'associated_places': []},
#  {'name': 'Seward:--', 'count': 1, 'associated_places': []},
#  {'name': 'Billingtons',
#   'count': 1,
#   'associated_places': [{'name': 'England', 'count': 1}]},
#  {'name': 'Carter Paterson', 'count': 1, 'associated_places': []},
#  {'name': 'Carter Patersons', 'count': 1, 'associated_places': []},
#  {'name': 'Blyme', 'count': 1, 'associated_places': []},
#  {'name': 'Mina Harkers', 'count': 1, 'associated_places': []},
#  {'name': 'Hennessey', 'count': 1, 'associated_places': []},
#  {'name': 'ignoratio elenchi_', 'count': 1, 'associated_places': []},
#  {'name': 'Harker:--', 'count': 1, 'associated_places': []},
#  {'name': 'Hun', 'count': 1, 'associated_places': []},
#  {'name': 'Voivode Dracula', 'count': 1, 'associated_places': []},
#  {'name': 'Windham', 'count': 1, 'associated_places': []},
#  {'name': 'Monroe', 'count': 1, 'associated_places': []},
#  {'name': 'Seward:-- Say', 'count': 1, 'associated_places': []},
#  {'name': 'Domine',
#   'count': 1,
#   'associated_places': [{'name': 'Transylvania', 'count': 1}]},
#  {'name': 'particulari', 'count': 1, 'associated_places': []},
#  {'name': 'Joseph Smollet', 'count': 1, 'associated_places': []},
#  {'name': 'Sam Bloxam', 'count': 1, 'associated_places': []},
#  {'name': 'ketch', 'count': 1, 'associated_places': []},
#  {'name': 'hand:-- Sam Bloxam', 'count': 1, 'associated_places': []},
#  {'name': 'Poters Cort', 'count': 1, 'associated_places': []},
#  {'name': 'Smollets', 'count': 1, 'associated_places': []},
#  {'name': 'somethink',
#   'count': 1,
#   'associated_places': [{'name': 'Texas', 'count': 1}]},
#  {'name': 'avin ad', 'count': 1, 'associated_places': []},
#  {'name': 'Mitchell', 'count': 1, 'associated_places': []},
#  {'name': 'replying:-- It', 'count': 1, 'associated_places': []},
#  {'name': 'Mitchells', 'count': 1, 'associated_places': []},
#  {'name': 'Malvolio', 'count': 1, 'associated_places': []},
#  {'name': 'zophagy', 'count': 1, 'associated_places': []},
#  {'name': 'Enochs', 'count': 1, 'associated_places': []},
#  {'name': 'Later._--I', 'count': 1, 'associated_places': []},
#  {'name': 'Archibald Winter', 'count': 1, 'associated_places': []},
#  {'name': 'over:--', 'count': 1, 'associated_places': []},
#  {'name': 'Simmons',
#   'count': 1,
#   'associated_places': [{'name': 'lovi', 'count': 1}]},
#  {'name': 'trephine', 'count': 1, 'associated_places': []},
#  {'name': 'Inured', 'count': 1, 'associated_places': []},
#  {'name': 'Moth', 'count': 1, 'associated_places': []},
#  {'name': 'Moon', 'count': 1, 'associated_places': []},
#  {'name': 'chin', 'count': 1, 'associated_places': []},
#  {'name': 'Godalming answered:--', 'count': 1, 'associated_places': []},
#  {'name': 'rgle_', 'count': 1, 'associated_places': []},
#  {'name': 'Friend Quincey', 'count': 1, 'associated_places': []},
#  {'name': 'Sacred Wafer', 'count': 1, 'associated_places': []},
#  {'name': 'Arminus of Buda-Pesth', 'count': 1, 'associated_places': []},
#  {'name': 'Johns', 'count': 1, 'associated_places': []},
#  {'name': 'Jonathan Harkers', 'count': 1, 'associated_places': []},
#  {'name': 'Madams', 'count': 1, 'associated_places': []},
#  {'name': 'Wafer', 'count': 1, 'associated_places': []},
#  {'name': 'Tally Ho', 'count': 1, 'associated_places': []},
#  {'name': 'sorrowfully:--', 'count': 1, 'associated_places': []},
#  {'name': 'Soh', 'count': 1, 'associated_places': []},
#  {'name': 'Doolittles Wharf', 'count': 1, 'associated_places': []},
#  {'name': 'Ristics', 'count': 1, 'associated_places': []},
#  {'name': 'bush', 'count': 1, 'associated_places': []},
#  {'name': 'on:-- Madam Mina', 'count': 1, 'associated_places': []},
#  {'name': 'Van Helsing continued:--', 'count': 1, 'associated_places': []},
#  {'name': 'Later._--At', 'count': 1, 'associated_places': []},
#  {'name': 'Winchester', 'count': 1, 'associated_places': []},
#  {'name': 'afternoon._--For', 'count': 1, 'associated_places': []},
#  {'name': 'a Recording Angel', 'count': 1, 'associated_places': []},
#  {'name': 'gravely:-- Madam Mina', 'count': 1, 'associated_places': []},
#  {'name': 'Varna._--We', 'count': 1, 'associated_places': []},
#  {'name': 'Moneybag', 'count': 1, 'associated_places': []},
#  {'name': 'H. B. M. Vice-Consul', 'count': 1, 'associated_places': []},
#  {'name': 'Ghoorka', 'count': 1, 'associated_places': []},
#  {'name': 'Later._--Our', 'count': 1, 'associated_places': []},
#  {'name': 'significantly:--', 'count': 1, 'associated_places': []},
#  {'name': 'H. B. M. Vice Consul', 'count': 1, 'associated_places': []},
#  {'name': 'Morris Quincey', 'count': 1, 'associated_places': []},
#  {'name': 'Hans Andersen', 'count': 1, 'associated_places': []},
#  {'name': 'Dos pou sto_', 'count': 1, 'associated_places': []},
#  {'name': 'Archimedes', 'count': 1, 'associated_places': []},
#  {'name': 'Lombroso',
#   'count': 1,
#   'associated_places': [{'name': 'Rig Mill', 'count': 1},
#    {'name': 'Runswick', 'count': 1}]},
#  {'name': 'Psalmist', 'count': 1, 'associated_places': []},
#  {'name': 'Sunrise', 'count': 1, 'associated_places': []},
#  {'name': 'Donelson', 'count': 1, 'associated_places': []},
#  {'name': 'Devil', 'count': 1, 'associated_places': []},
#  {'name': 'Hildesheim', 'count': 1, 'associated_places': []},
#  {'name': 'de Ville', 'count': 1, 'associated_places': []},
#  {'name': 'Mina Harkers Memorandum', 'count': 1, 'associated_places': []},
#  {'name': 'Firstly._--We', 'count': 1, 'associated_places': []},
#  {'name': 'Donelsons', 'count': 1, 'associated_places': []},
#  {'name': 'Counts', 'count': 1, 'associated_places': []},
#  {'name': 'Morris:--', 'count': 1, 'associated_places': []},
#  {'name': 'Friend Jonathan', 'count': 1, 'associated_places': []},
#  {'name': 'Jonathan went,--from Bistritz',
#   'count': 1,
#   'associated_places': []},
#  {'name': 'Borgo', 'count': 1, 'associated_places': []},
#  {'name': 'Later._--Oh', 'count': 1, 'associated_places': []},
#  {'name': 'Bistritza', 'count': 1, 'associated_places': []},
#  {'name': 'grey', 'count': 1, 'associated_places': []},
#  {'name': 'Van Helsings Memorandum', 'count': 1, 'associated_places': []},
#  {'name': 'him_--whom',
#   'count': 1,
#   'associated_places': [{'name': 'Varna', 'count': 1},
#    {'name': 'Whitby', 'count': 1}]},
#  {'name': 'Down', 'count': 1, 'associated_places': []},
#  {'name': 'said:--', 'count': 1, 'associated_places': []},
#  {'name': 'JONATHAN HARKER', 'count': 1, 'associated_places': []},
#  {'name': 'J. S. FLETCHER', 'count': 1, 'associated_places': []},
#  {'name': 'Gazette', 'count': 1, 'associated_places': []},
#  {'name': 'md sight=>', 'count': 1, 'associated_places': []},
#  {'name': 'Redistributing Project Gutenberg',
#   'count': 1,
#   'associated_places': []},
#  {'name': 'Project Gutenbergs', 'count': 1, 'associated_places': []},
#  {'name': 'Michael S. Hart', 'count': 1, 'associated_places': []}]
